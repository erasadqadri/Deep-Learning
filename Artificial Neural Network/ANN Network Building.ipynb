# %% [markdown]
# # **Artificial Neural Network**
#
# # Part 1 - Data Preprocessing

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing the dataset
dataset = pd.read_csv('/content/drive/MyDrive/Deep Learning/Datasets/KNDataSets/Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
X = dataset.iloc[:, 3:13] #all rows and index 3 to 12 columns
X.head()
# Out:
#    CreditScore Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619    France  Female  ...          1               1        101348.88
# 1          608     Spain  Female  ...          0               1        112542.58
# 2          502    France  Female  ...          1               0        113931.57
# 3          699    France  Female  ...          0               0         93826.63
# 4          850     Spain  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
X.shape
# Out:
# (10000, 10)

# %%
y = dataset.iloc[:, 13] #all rows and only index 13 columns
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
geography.head()
# Out:
#    Germany  Spain
# 0        0      0
# 1        0      1
# 2        0      0
# 3        0      0
# 4        0      1

# %%
gender=pd.get_dummies(X['Gender'],drop_first=True)
gender.head()
# Out:
#    Male
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
#Concatenate the Data Frames
X=pd.concat([X,geography,gender],axis=1)
X.head()
# Out:
#    CreditScore Geography  Gender  Age  ...  EstimatedSalary  Germany  Spain  Male
# 0          619    France  Female   42  ...        101348.88        0      0     0
# 1          608     Spain  Female   41  ...        112542.58        0      1     0
# 2          502    France  Female   42  ...        113931.57        0      0     0
# 3          699    France  Female   39  ...         93826.63        0      0     0
# 4          850     Spain  Female   43  ...         79084.10        0      1     0
#
# [5 rows x 13 columns]

# %%
#Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  ...  EstimatedSalary  Germany  Spain  Male
# 0          619   42       2       0.00  ...        101348.88        0      0     0
# 1          608   41       1   83807.86  ...        112542.58        0      1     0
# 2          502   42       8  159660.80  ...        113931.57        0      0     0
# 3          699   39       1       0.00  ...         93826.63        0      0     0
# 4          850   43       2  125510.82  ...         79084.10        0      1     0
#
# [5 rows x 11 columns]

# %%
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 11)

# %% [markdown]
# # Part 2 - Preparing ANN!

# %%
# Importing Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11)) #input_dim = 11 bcoz input features in X_train are 11

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 6s 5ms/step - loss: 0.5671 - accuracy: 0.7953 - val_loss: 0.5166 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4983 - accuracy: 0.7962 - val_loss: 0.4819 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4673 - accuracy: 0.7962 - val_loss: 0.4608 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4472 - accuracy: 0.7962 - val_loss: 0.4471 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4339 - accuracy: 0.7962 - val_loss: 0.4370 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4254 - accuracy: 0.7962 - val_loss: 0.4293 - val_accuracy: 0.7955
# Epoch 7/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4174 - accuracy: 0.8117 - val_loss: 0.4217 - val_accuracy: 0.8099
# Epoch 8/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4055 - accuracy: 0.8289 - val_loss: 0.4077 - val_accuracy: 0.8236
# Epoch 9/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3891 - accuracy: 0.8406 - val_loss: 0.3932 - val_accuracy: 0.8307
# Epoch 10/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3746 - accuracy: 0.8464 - val_loss: 0.3836 - val_accuracy: 0.8368
# Epoch 11/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3652 - accuracy: 0.8548 - val_loss: 0.3775 - val_accuracy: 0.8406
# Epoch 12/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3595 - accuracy: 0.8537 - val_loss: 0.3736 - val_accuracy: 0.8463
# Epoch 13/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3553 - accuracy: 0.8565 - val_loss: 0.3714 - val_accuracy: 0.8432
# Epoch 14/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3525 - accuracy: 0.8584 - val_loss: 0.3703 - val_accuracy: 0.8478
# Epoch 15/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3504 - accuracy: 0.8556 - val_loss: 0.3701 - val_accuracy: 0.8444
# Epoch 16/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3488 - accuracy: 0.8559 - val_loss: 0.3696 - val_accuracy: 0.8459
# Epoch 17/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3473 - accuracy: 0.8571 - val_loss: 0.3698 - val_accuracy: 0.8417
# Epoch 18/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3466 - accuracy: 0.8572 - val_loss: 0.3686 - val_accuracy: 0.8459
# Epoch 19/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3453 - accuracy: 0.8584 - val_loss: 0.3693 - val_accuracy: 0.8436
# Epoch 20/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3447 - accuracy: 0.8591 - val_loss: 0.3678 - val_accuracy: 0.8463
# Epoch 21/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3435 - accuracy: 0.8608 - val_loss: 0.3683 - val_accuracy: 0.8466
# Epoch 22/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3432 - accuracy: 0.8610 - val_loss: 0.3677 - val_accuracy: 0.8455
# Epoch 23/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3426 - accuracy: 0.8595 - val_loss: 0.3674 - val_accuracy: 0.8440
# Epoch 24/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3419 - accuracy: 0.8625 - val_loss: 0.3674 - val_accuracy: 0.8474
# Epoch 25/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3417 - accuracy: 0.8602 - val_loss: 0.3667 - val_accuracy: 0.8466
# Epoch 26/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3410 - accuracy: 0.8640 - val_loss: 0.3665 - val_accuracy: 0.8463
# Epoch 27/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3409 - accuracy: 0.8627 - val_loss: 0.3669 - val_accuracy: 0.8425
# Epoch 28/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3401 - accuracy: 0.8636 - val_loss: 0.3663 - val_accuracy: 0.8463
# Epoch 29/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3394 - accuracy: 0.8640 - val_loss: 0.3665 - val_accuracy: 0.8466
# Epoch 30/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3390 - accuracy: 0.8602 - val_loss: 0.3657 - val_accuracy: 0.8466
# Epoch 31/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3386 - accuracy: 0.8623 - val_loss: 0.3668 - val_accuracy: 0.8470
# Epoch 32/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3383 - accuracy: 0.8614 - val_loss: 0.3661 - val_accuracy: 0.8459
# Epoch 33/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3384 - accuracy: 0.8628 - val_loss: 0.3660 - val_accuracy: 0.8463
# Epoch 34/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3375 - accuracy: 0.8649 - val_loss: 0.3668 - val_accuracy: 0.8440
# Epoch 35/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3378 - accuracy: 0.8599 - val_loss: 0.3651 - val_accuracy: 0.8463
# Epoch 36/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3376 - accuracy: 0.8617 - val_loss: 0.3651 - val_accuracy: 0.8470
# Epoch 37/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3371 - accuracy: 0.8638 - val_loss: 0.3660 - val_accuracy: 0.8451
# Epoch 38/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3370 - accuracy: 0.8630 - val_loss: 0.3660 - val_accuracy: 0.8463
# Epoch 39/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3365 - accuracy: 0.8636 - val_loss: 0.3655 - val_accuracy: 0.8436
# Epoch 40/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3365 - accuracy: 0.8608 - val_loss: 0.3647 - val_accuracy: 0.8448
# Epoch 41/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3364 - accuracy: 0.8625 - val_loss: 0.3646 - val_accuracy: 0.8436
# Epoch 42/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3360 - accuracy: 0.8627 - val_loss: 0.3658 - val_accuracy: 0.8448
# Epoch 43/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3359 - accuracy: 0.8623 - val_loss: 0.3652 - val_accuracy: 0.8444
# Epoch 44/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3356 - accuracy: 0.8632 - val_loss: 0.3655 - val_accuracy: 0.8440
# Epoch 45/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3357 - accuracy: 0.8608 - val_loss: 0.3651 - val_accuracy: 0.8455
# Epoch 46/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3355 - accuracy: 0.8632 - val_loss: 0.3651 - val_accuracy: 0.8444
# Epoch 47/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3349 - accuracy: 0.8627 - val_loss: 0.3647 - val_accuracy: 0.8444
# Epoch 48/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3349 - accuracy: 0.8632 - val_loss: 0.3649 - val_accuracy: 0.8421
# Epoch 49/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3347 - accuracy: 0.8627 - val_loss: 0.3653 - val_accuracy: 0.8455
# Epoch 50/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3347 - accuracy: 0.8628 - val_loss: 0.3643 - val_accuracy: 0.8451
# Epoch 51/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3342 - accuracy: 0.8621 - val_loss: 0.3651 - val_accuracy: 0.8444
# Epoch 52/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3343 - accuracy: 0.8628 - val_loss: 0.3645 - val_accuracy: 0.8444
# Epoch 53/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3341 - accuracy: 0.8617 - val_loss: 0.3641 - val_accuracy: 0.8459
# Epoch 54/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3340 - accuracy: 0.8615 - val_loss: 0.3650 - val_accuracy: 0.8440
# Epoch 55/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3335 - accuracy: 0.8632 - val_loss: 0.3642 - val_accuracy: 0.8432
# Epoch 56/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3340 - accuracy: 0.8623 - val_loss: 0.3647 - val_accuracy: 0.8425
# Epoch 57/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3338 - accuracy: 0.8623 - val_loss: 0.3643 - val_accuracy: 0.8455
# Epoch 58/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3336 - accuracy: 0.8630 - val_loss: 0.3646 - val_accuracy: 0.8463
# Epoch 59/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3334 - accuracy: 0.8625 - val_loss: 0.3639 - val_accuracy: 0.8448
# Epoch 60/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3334 - accuracy: 0.8617 - val_loss: 0.3633 - val_accuracy: 0.8455
# Epoch 61/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3332 - accuracy: 0.8625 - val_loss: 0.3633 - val_accuracy: 0.8448
# Epoch 62/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3327 - accuracy: 0.8623 - val_loss: 0.3643 - val_accuracy: 0.8432
# Epoch 63/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3332 - accuracy: 0.8627 - val_loss: 0.3637 - val_accuracy: 0.8451
# Epoch 64/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3330 - accuracy: 0.8623 - val_loss: 0.3633 - val_accuracy: 0.8448
# Epoch 65/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3328 - accuracy: 0.8636 - val_loss: 0.3634 - val_accuracy: 0.8451
# Epoch 66/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3324 - accuracy: 0.8614 - val_loss: 0.3639 - val_accuracy: 0.8425
# Epoch 67/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3327 - accuracy: 0.8638 - val_loss: 0.3622 - val_accuracy: 0.8455
# Epoch 68/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3325 - accuracy: 0.8614 - val_loss: 0.3629 - val_accuracy: 0.8451
# Epoch 69/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3323 - accuracy: 0.8640 - val_loss: 0.3633 - val_accuracy: 0.8451
# Epoch 70/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3323 - accuracy: 0.8640 - val_loss: 0.3635 - val_accuracy: 0.8444
# Epoch 71/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3321 - accuracy: 0.8615 - val_loss: 0.3646 - val_accuracy: 0.8451
# Epoch 72/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3322 - accuracy: 0.8628 - val_loss: 0.3627 - val_accuracy: 0.8436
# Epoch 73/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3323 - accuracy: 0.8627 - val_loss: 0.3626 - val_accuracy: 0.8432
# Epoch 74/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3323 - accuracy: 0.8632 - val_loss: 0.3625 - val_accuracy: 0.8425
# Epoch 75/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3317 - accuracy: 0.8621 - val_loss: 0.3640 - val_accuracy: 0.8436
# Epoch 76/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3321 - accuracy: 0.8619 - val_loss: 0.3622 - val_accuracy: 0.8444
# Epoch 77/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3315 - accuracy: 0.8623 - val_loss: 0.3619 - val_accuracy: 0.8436
# Epoch 78/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3319 - accuracy: 0.8610 - val_loss: 0.3624 - val_accuracy: 0.8436
# Epoch 79/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.3318 - accuracy: 0.8615 - val_loss: 0.3625 - val_accuracy: 0.8448
# Epoch 80/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3318 - accuracy: 0.8617 - val_loss: 0.3627 - val_accuracy: 0.8448
# Epoch 81/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3316 - accuracy: 0.8630 - val_loss: 0.3623 - val_accuracy: 0.8444
# Epoch 82/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3316 - accuracy: 0.8617 - val_loss: 0.3619 - val_accuracy: 0.8444
# Epoch 83/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3316 - accuracy: 0.8619 - val_loss: 0.3637 - val_accuracy: 0.8444
# Epoch 84/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3313 - accuracy: 0.8617 - val_loss: 0.3616 - val_accuracy: 0.8432
# Epoch 85/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3312 - accuracy: 0.8640 - val_loss: 0.3639 - val_accuracy: 0.8455
# Epoch 86/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3311 - accuracy: 0.8619 - val_loss: 0.3631 - val_accuracy: 0.8478
# Epoch 87/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3306 - accuracy: 0.8625 - val_loss: 0.3619 - val_accuracy: 0.8429
# Epoch 88/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3311 - accuracy: 0.8615 - val_loss: 0.3627 - val_accuracy: 0.8451
# Epoch 89/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3306 - accuracy: 0.8634 - val_loss: 0.3630 - val_accuracy: 0.8451
# Epoch 90/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3311 - accuracy: 0.8628 - val_loss: 0.3619 - val_accuracy: 0.8436
# Epoch 91/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3311 - accuracy: 0.8625 - val_loss: 0.3616 - val_accuracy: 0.8432
# Epoch 92/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3308 - accuracy: 0.8623 - val_loss: 0.3616 - val_accuracy: 0.8425
# Epoch 93/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3311 - accuracy: 0.8642 - val_loss: 0.3623 - val_accuracy: 0.8466
# Epoch 94/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3311 - accuracy: 0.8606 - val_loss: 0.3618 - val_accuracy: 0.8463
# Epoch 95/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3308 - accuracy: 0.8636 - val_loss: 0.3606 - val_accuracy: 0.8444
# Epoch 96/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3310 - accuracy: 0.8628 - val_loss: 0.3615 - val_accuracy: 0.8451
# Epoch 97/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3304 - accuracy: 0.8638 - val_loss: 0.3615 - val_accuracy: 0.8444
# Epoch 98/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3310 - accuracy: 0.8614 - val_loss: 0.3617 - val_accuracy: 0.8463
# Epoch 99/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3303 - accuracy: 0.8638 - val_loss: 0.3618 - val_accuracy: 0.8444
# Epoch 100/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3302 - accuracy: 0.8621 - val_loss: 0.3613 - val_accuracy: 0.8440

# %%
# list of all data in history
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'], color='red')
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'], color = 'green')
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Part 3 - Making predictions and evaluating model

# %%
# Predicting test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Calculating accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8535

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1496,   99],
#        [ 194,  211]])
